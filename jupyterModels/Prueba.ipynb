# %%
import tensorflow as tf
from tensorflow import keras
import os
import pandas as pd
from tensorflow.keras.applications import ResNet50V2
from sklearn.model_selection import StratifiedKFold
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import imageio

# %%
baseline2 = keras.models.load_model('models/baseline2.h5')
baseline2.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 256, 256, 3)]     0
#
#  rescaling_4 (Rescaling)     (None, 256, 256, 3)       0
#
#  resnet50v2 (Functional)     (None, 8, 8, 2048)        23564800
#
#  global_average_pooling2d_4   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 23,566,849
# Trainable params: 2,049
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %%
TRAIN_PATH = 'datasets/ISIC_2020_corrected/train_resized'
train_images = os.listdir(TRAIN_PATH)
img = Image.open(f'{TRAIN_PATH}/{train_images[0]}')
img.size
# Out:
# (256, 256)

# %%
num = 0
for img in range(1000):
    image = imageio.v2.imread(f'{TRAIN_PATH}/{train_images[img]}')
    image = np.expand_dims(image, axis=0)
    pred = baseline2(image)
    if pred > 0.5:
        num += 1
        print(f'{num}, {pred}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       3 image = imageio.v2.imread(f'{TRAIN_PATH}/{train_images[img]}')
#       4 image = np.expand_dims(image, axis=0)
# ----> 5 pred = baseline2(image)
#       6 if pred > 0.5:
#       7     num += 1
#
# File ~\Desktop\Pablo\TFG\PythonEnv\.venv\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\Desktop\Pablo\TFG\PythonEnv\.venv\lib\site-packages\keras\engine\base_layer.py:1096, in Layer.__call__(self, *args, **kwargs)
#    1092   inputs = self._maybe_cast_inputs(inputs, input_list)
#    1094 with autocast_variable.enable_auto_cast_variables(
#    1095     self._compute_dtype_object):
# -> 1096   outputs = call_fn(inputs, *args, **kwargs)
#    1098 if self._activity_regularizer:
#    1099   self._handle_activity_regularization(inputs, outputs)
#
# File ~\Desktop\Pablo\TFG\PythonEnv\.venv\lib\site-packages\keras\utils\traceback_utils.py:92, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      90 bound_signature = None
#      91 try:
# ---> 92   return fn(*args, **kwargs)
#      93 except Exception as e:  # pylint: disable=broad-except
#      94   if hasattr(e, '_keras_call_info_injected'):
#      95     # Only inject info for the innermost failing call
#
# File ~\Desktop\Pablo\TFG\PythonEnv\.venv\lib\site-packages\keras\engine\functional.py:451, in Functional.call(self, inputs, training, mask)
#     432 @doc_controls.do_not_doc_inheritable
#     433 def call(self, inputs, training=None, mask=None):
#     434   """Calls the model on new inputs.
#     435
#     436   In this case `call` just reapplies
#    (...)
#     449       a list of tensors if there are more than one outputs.
#     450   """
# --> 451   return self._run_internal_graph(
#     452       inputs, training=training, mask=mask)
#
# File ~\Desktop\Pablo\TFG\PythonEnv\.venv\lib\site-packages\keras\engine\functional.py:589, in Functional._run_internal_graph(self, inputs, training, mask)
#     586   continue  # Node is not computable, try skipping.
#     588 args, kwargs = node.map_arguments(tensor_dict)
# --> 589 outputs = node.layer(*args, **kwargs)
#     591 # Update tensor_dict.
#     592 for x_id, y in zip(node.flat_output_ids, tf.nest.flatten(outputs)):
#
# File ~\Desktop\Pablo\TFG\PythonEnv\.venv\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\Desktop\Pablo\TFG\PythonEnv\.venv\lib\site-packages\keras\engine\base_layer.py:1096, in Layer.__call__(self, *args, **kwargs)
#    1092   inputs = self._maybe_cast_inputs(inputs, input_list)
#    1094 with autocast_variable.enable_auto_cast_variables(
#    1095     self._compute_dtype_object):
# -> 1096   outputs = call_fn(inputs, *args, **kwargs)
#    1098 if self._activity_regularizer:
#    1099   self._handle_activity_regularization(inputs, outputs)
#
# File ~\Desktop\Pablo\TFG\PythonEnv\.venv\lib\site-packages\keras\utils\traceback_utils.py:92, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      90 bound_signature = None
#      91 try:
# ---> 92   return fn(*args, **kwargs)
#      93 except Exception as e:  # pylint: disable=broad-except
#      94   if hasattr(e, '_keras_call_info_injected'):
#      95     # Only inject info for the innermost failing call
#
# File ~\Desktop\Pablo\TFG\PythonEnv\.venv\lib\site-packages\keras\engine\functional.py:451, in Functional.call(self, inputs, training, mask)
#     432 @doc_controls.do_not_doc_inheritable
#     433 def call(self, inputs, training=None, mask=None):
#     434   """Calls the model on new inputs.
#     435
#     436   In this case `call` just reapplies
#    (...)
#     449       a list of tensors if there are more than one outputs.
#     450   """
# --> 451   return self._run_internal_graph(
#     452       inputs, training=training, mask=mask)
#
# File ~\Desktop\Pablo\TFG\PythonEnv\.venv\lib\site-packages\keras\engine\functional.py:589, in Functional._run_internal_graph(self, inputs, training, mask)
#     586   continue  # Node is not computable, try skipping.
#     588 args, kwargs = node.map_arguments(tensor_dict)
# --> 589 outputs = node.layer(*args, **kwargs)
#     591 # Update tensor_dict.
#     592 for x_id, y in zip(node.flat_output_ids, tf.nest.flatten(outputs)):
#
# File ~\Desktop\Pablo\TFG\PythonEnv\.venv\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\Desktop\Pablo\TFG\PythonEnv\.venv\lib\site-packages\keras\engine\base_layer.py:1096, in Layer.__call__(self, *args, **kwargs)
#    1092   inputs = self._maybe_cast_inputs(inputs, input_list)
#    1094 with autocast_variable.enable_auto_cast_variables(
#    1095     self._compute_dtype_object):
# -> 1096   outputs = call_fn(inputs, *args, **kwargs)
#    1098 if self._activity_regularizer:
#    1099   self._handle_activity_regularization(inputs, outputs)
#
# File ~\Desktop\Pablo\TFG\PythonEnv\.venv\lib\site-packages\keras\utils\traceback_utils.py:92, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      90 bound_signature = None
#      91 try:
# ---> 92   return fn(*args, **kwargs)
#      93 except Exception as e:  # pylint: disable=broad-except
#      94   if hasattr(e, '_keras_call_info_injected'):
#      95     # Only inject info for the innermost failing call
#
# File ~\Desktop\Pablo\TFG\PythonEnv\.venv\lib\site-packages\keras\layers\merge.py:183, in _Merge.call(self, inputs)
#     181     return y
#     182 else:
# --> 183   return self._merge_function(inputs)
#
# File ~\Desktop\Pablo\TFG\PythonEnv\.venv\lib\site-packages\keras\layers\merge.py:259, in Add._merge_function(self, inputs)
#     257 output = inputs[0]
#     258 for i in range(1, len(inputs)):
# --> 259   output += inputs[i]
#     260 return output
#
# File ~\Desktop\Pablo\TFG\PythonEnv\.venv\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\Desktop\Pablo\TFG\PythonEnv\.venv\lib\site-packages\tensorflow\python\ops\math_ops.py:1406, in _OverrideBinaryOperatorHelper.<locals>.binary_op_wrapper(x, y)
#    1401 try:
#    1402   # force_same_dtype=False to preserve existing TF behavior
#    1403   # TODO(b/178860388): Figure out why binary_op_wrapper and
#    1404   #   r_binary_op_wrapper use different force_same_dtype values.
#    1405   x, y = maybe_promote_tensors(x, y)
# -> 1406   return func(x, y, name=name)
#    1407 except (TypeError, ValueError) as e:
#    1408   # Even if dispatching the op failed, the RHS may be a tensor aware
#    1409   # object that can implement the operator with knowledge of itself
#    (...)
#    1412   # original error from the LHS, because it may be more
#    1413   # informative.
#    1414   if hasattr(type(y), "__r%s__" % op_name):
#
# File ~\Desktop\Pablo\TFG\PythonEnv\.venv\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\Desktop\Pablo\TFG\PythonEnv\.venv\lib\site-packages\tensorflow\python\util\dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\Desktop\Pablo\TFG\PythonEnv\.venv\lib\site-packages\tensorflow\python\ops\math_ops.py:1756, in _add_dispatch(x, y, name)
#    1754   return gen_math_ops.add(x, y, name=name)
#    1755 else:
# -> 1756   return gen_math_ops.add_v2(x, y, name=name)
#
# File ~\Desktop\Pablo\TFG\PythonEnv\.venv\lib\site-packages\tensorflow\python\ops\gen_math_ops.py:461, in add_v2(x, y, name)
#     459 if tld.is_eager:
#     460   try:
# --> 461     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     462       _ctx, "AddV2", name, x, y)
#     463     return _result
#     464   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
image = imageio.v2.imread(f'{TRAIN_PATH}/{train_images[0]}')
image = np.expand_dims(image, axis=0)
baseline2(image).numpy()[0][0]
# Out:
# 0.0027806498

# %%
PATH = 'datasets/ISIC_2020_corrected'
test = pd.read_csv(f'{PATH}/test_split.csv')
BATCH_SIZE = 64
AUTO = tf.data.experimental.AUTOTUNE

def decode(name, label):
    img = tf.io.read_file(name)
    img = tf.image.decode_jpeg(img, channels = 3)
    img = tf.cast(img, tf.float32)
    return img, label
    
def load_ds(df):
    options = tf.data.Options()
    options.experimental_deterministic = False
    imgs, labels = df["image_name"].values, df["target"].values
    imgs = [f'{PATH}/train_resized/{name}.jpg' for name in imgs]
    ds = tf.data.Dataset.from_tensor_slices((imgs, labels))
    ds = ds.with_options(options)
    ds = ds.map(decode, num_parallel_calls=AUTO)
    ds = ds.cache()
    ds = ds.shuffle(2048)
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTO)
    return ds
test_ds = load_ds(test)
baseline2.evaluate(test_ds)
# Out:
# 78/78 [==============================] - 13s 143ms/step - loss: 0.0729 - auc: 0.8479
# [0.07291726768016815, 0.8479295372962952]

# %%
malignant = test.loc[test.index[test['target'] == 1]]
benign = test.loc[test.index[test['target'] == 0]]
malignant
# Out:
#         image_name  patient_id   lesion_id     sex  age_approx  \
# 208   ISIC_6971606  IP_9375901  IL_9213093  female        25.0
# 221   ISIC_8724944  IP_3089004  IL_7415900  female        45.0
# 227   ISIC_1255336  IP_7650895  IL_3080866  female        65.0
# 278   ISIC_3023646  IP_6658881  IL_3206915    male        80.0
# 312   ISIC_2320481  IP_9205637  IL_1645335    male        65.0
# ...            ...         ...         ...     ...         ...
# 4536  ISIC_0914168  IP_3659172  IL_7413123  female        50.0
# 4577  ISIC_8866651  IP_8375879  IL_4249218    male        75.0
# 4583  ISIC_7960321  IP_4327880  IL_7205523    male        75.0
# 4632  ISIC_3697702  IP_2809878  IL_9287863  female        45.0
# 4869  ISIC_8252406  IP_3750016  IL_8184686    male        85.0
#
#      anatom_site_general_challenge diagnosis benign_malignant  target
# 208                          torso  melanoma        malignant       1
# 221                          torso  melanoma        malignant       1
# 227                lower extremity  melanoma        malignant       1
# 278                      head/neck  melanoma        malignant       1
# 312                          torso  melanoma        malignant       1
# ...                            ...       ...              ...     ...
# 4536                         torso  melanoma        malignant       1
# 4577                         torso  melanoma        malignant       1
# 4583                         torso  melanoma        malignant       1
# 4632                         torso  melanoma        malignant       1
# 4869                   palms/soles  melanoma        malignant       1
#
# [87 rows x 9 columns]

# %%
predictions = []
for name in list(malignant['image_name']):
    image = imageio.v2.imread(f'{TRAIN_PATH}/{name}.jpg')
    image = np.expand_dims(image, axis=0)
    predictions.append(baseline2(image).numpy()[0][0])

# %%
max(predictions), min(predictions), np.mean(predictions)
# Out:
# (0.54181457, 0.0010828365, 0.09205508)

# %%
predictions_b = []
for name in list(benign['image_name']):
    image = imageio.v2.imread(f'{TRAIN_PATH}/{name}.jpg')
    image = np.expand_dims(image, axis=0)
    predictions_b.append(baseline2(image).numpy()[0][0])
# Out:
# KeyboardInterrupt

# %%
max(predictions_b), min(predictions_b), np.mean(predictions_b)

# %%
plt.plot(predictions)

# %%
plt.plot(predictions_b)

# %%
ranges = [(0.0, 0.01),(0.01, 0.015), (0.015, 0.025),(0.025, 0.05), (0.05, 0.1), (0.1, 0.2), (0.2, 0.5), (0.5, 1)]
groups = [0, 0, 0, 0, 0, 0, 0, 0]
for p in predictions:
    i = 0
    for r in ranges:
        if p > r[0] and p <= r[1]:
            groups[i] += 1
        i += 1
plt.plot(groups)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 baseline2.thresholds()
#
# AttributeError: 'Functional' object has no attribute 'thresholds'

# %%
groups_b = [0, 0, 0, 0, 0, 0, 0, 0]
for p in predictions_b:
    i = 0
    for r in ranges:
        if p > r[0] and p <= r[1]:
            groups_b[i] += 1
        i += 1

# %%
labels = ['0', '1', '2', '3', '4', '5', '6','7']
width=0.35
X_axis = np.arange(len(labels))

fig, ax = plt.subplots(figsize=(10,10))


b1 = plt.bar(x = X_axis-0.2, height=[g/len(predictions)*100 for g in groups],width = width, label='malign')
b2 = plt.bar(x = X_axis+0.2, height=[g/len(predictions_b)*100 for g in groups_b],width = width, label='benign')

ax.set_ylabel('%')
ax.set_title('Results')
ax.set_xticks(X_axis, labels)
ax.legend()

ax.bar_label(b1, padding=3)
ax.bar_label(b2, padding=3)

plt.show()

# %%
import sklearn
from sklearn.metrics import roc_curve
all_predictions = predictions
fpr, tpr, thresholds  roc_curve()
