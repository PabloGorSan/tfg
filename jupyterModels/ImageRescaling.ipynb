# %%
from skimage.transform import resize

RESIZED_PATH = 'datasets/ISIC_2020_corrected/train_resized'
IMG_SHAPE = (256,256)
img_name = train_csv["image_name"].values

for i in range(img_name.size):
    img = Image.open(f'datasets/ISIC_2020_corrected/train/{img_name[i]}.jpg')
    resized_img = img.resize(IMG_SHAPE)
    resized_img.save(f'{RESIZED_PATH}/{img_name[i]}.jpg')
